# %%
#@title Step 1: Imports

import pandas as pd
import numpy as np
import math
import torch
# %matplotlib inline
import matplotlib.pyplot as plt  
import os                       
import sklearn.datasets         
from torch.utils.tensorboard import SummaryWriter
import json
import copy
from sklearn.model_selection import train_test_split

# %%
#@title Step 2: Download data
# !pip install kaggle

# !mkdir ~/.kaggle

kaggle_username = "wmd0701" #@param {type:"string"}
kaggle_api_key = "8f525bc765511d324f8509b938d7f39c" #@param {type:"string"}

assert len(kaggle_username) > 0 and len(kaggle_api_key) > 0

api_token = {"username": kaggle_username,"key": kaggle_api_key}

with open('kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !mv kaggle.json ~/.kaggle/kaggle.json

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c cil-collaborative-filtering-2021

# !unzip data_train.csv.zip 
# !unzip sampleSubmission.csv.zip
print()

number_of_users, number_of_movies = (10000, 1000)

data_pd = pd.read_csv('data_train.csv')
print(data_pd.head(5))
print('\nShape', data_pd.shape)

submission_pd = pd.read_csv('sampleSubmission.csv.zip')
print("\n\n",submission_pd.head(5))
print("\nShape:", submission_pd.shape)
print("\n\nSummary:", np.unique(data_pd.Prediction.values, return_counts=True))

sparsity = 1.0 - data_pd.shape[0] / (number_of_users * number_of_movies)
print("\nSparsity:", sparsity)
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading data_train.csv.zip to /content
#   0% 0.00/3.33M [00:00<?, ?B/s]
# 100% 3.33M/3.33M [00:00<00:00, 109MB/s]
# Downloading sampleSubmission.csv.zip to /content
#   0% 0.00/2.92M [00:00<?, ?B/s]
# 100% 2.92M/2.92M [00:00<00:00, 95.9MB/s]
# Archive:  data_train.csv.zip
#   inflating: data_train.csv
# Archive:  sampleSubmission.csv.zip
#   inflating: sampleSubmission.csv
#
#        Id  Prediction
# 0  r44_c1           4
# 1  r61_c1           3
# 2  r67_c1           4
# 3  r72_c1           3
# 4  r86_c1           5
#
# Shape (1176952, 2)
#
#
#          Id  Prediction
# 0   r37_c1           3
# 1   r73_c1           3
# 2  r156_c1           3
# 3  r160_c1           3
# 4  r248_c1           3
#
# Shape: (1176952, 2)
#
#
# Summary: (array([1, 2, 3, 4, 5]), array([ 43508,  99180, 274327, 324700, 435237]))
#
# Sparsity: 0.8823048

# %%
#@title Step 3: Split data

train_size = 0.9

train_pd, test_pd = train_test_split(data_pd, train_size=train_size, random_state=0)
print(train_pd.shape)
print(test_pd.shape)

def extract_users_items_predictions(data_pd):
    users, movies = \
        [np.squeeze(arr) for arr in np.split(data_pd.Id.str.extract('r(\d+)_c(\d+)').values.astype(int) - 1, 2, axis=-1)]
    predictions = data_pd.Prediction.values
    return users, movies, predictions

train_users, train_movies, train_predictions = extract_users_items_predictions(train_pd)
test_users, test_movies, test_predictions = extract_users_items_predictions(test_pd)
all_users, all_movies, all_predictions = extract_users_items_predictions(data_pd)
# Out:
# (1059256, 2)
# (117696, 2)

# %%
#@title Step 4: Use GPU if available

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device is {device}.")
# Out:
# Device is cuda.

# %%
#@title Step 5: Create data loaders
batch_size = 64

# datasets and data loaders for training/validation
train_users_  = torch.tensor(train_users, device=device).int()
train_movies_ = torch.tensor(train_movies, device=device).int()
train_predictions_ = torch.tensor(train_predictions, device=device).float()
test_users_  = torch.tensor(test_users, device=device).int()
test_movies_ = torch.tensor(test_movies, device=device).int()
test_predictions_ = torch.tensor(test_predictions, device=device).float()
train_set = torch.utils.data.TensorDataset(train_users_, train_movies_, train_predictions_)
test_set  = torch.utils.data.TensorDataset(test_users_ , test_movies_ , test_predictions_)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader  = torch.utils.data.DataLoader(test_set , batch_size=batch_size, shuffle=False)

# datasets and data loaders for the whole task
all_users_  = torch.tensor(all_users, device=device).int()
all_movies_ = torch.tensor(all_movies, device=device).int()
all_predictions_ = torch.tensor(all_predictions, device=device).float()
all_set = torch.utils.data.TensorDataset(all_users_, all_movies_, all_predictions_)
all_loader = torch.utils.data.DataLoader(all_set , batch_size=batch_size, shuffle=True)

print(len(train_loader))
print(len(test_loader))
print(len(all_loader))
# Out:
# 16551
# 1839
# 18390

# %%
#@title Step 6: SVD++ class

class SVDpp(torch.nn.Module):
  def __init__(self, number_of_users=number_of_users, number_of_movies=number_of_movies, rank=20, biased=True):
    super().__init__()
    self.biased = biased
    self.rank = rank
    self.user_matrix   = torch.nn.Embedding(number_of_users , self.rank)
    self.movie_matrix  = torch.nn.Embedding(number_of_movies, self.rank)
    self.user_biases   = torch.nn.Embedding(number_of_users , 1)
    self.movie_biases  = torch.nn.Embedding(number_of_movies, 1)
    self.global_biases = torch.nn.Embedding(1, 1)

    # constants
    self.zero = torch.tensor(0).to(device)
    self.register_buffer('const_zero', self.zero)


  def forward(self, user, movie):
    pred  = (self.user_matrix(user) * self.movie_matrix(movie)).sum(1, keepdim=True)
    if self.biased:
      pred += self.user_biases(user) + self.movie_biases(movie) + self.global_biases(self.zero)
    
    return pred.squeeze()


  def SVD_init(self, using_all_data=False): 
    print("using SVD initialization")

    data = np.full((number_of_users, number_of_movies), np.mean(data_pd.Prediction.values))
    if using_all_data:
      for user, movie, pred in zip(all_users, all_movies, all_predictions):
        data[user][movie] = pred
    else:
      for user, movie, pred in zip(train_users, train_movies, train_predictions):
        data[user][movie] = pred
    print("SVD done")

    U, s, Vt = np.linalg.svd(data, full_matrices=False)
    print("original U  shape:", U.shape)
    print("original Vt shape:", Vt.shape)
    print("original s  shape:", s.shape)
    U = U[:, :self.rank]
    V = Vt.T
    V = V[:, :self.rank]
    print("cut-off U shape:", U.shape)
    print("cut-off V shape:", V.shape)
    
    for i in range(self.rank):
      U[:, i] *= np.sqrt(s[i])
      V[:, i] *= np.sqrt(s[i])
    self.user_matrix.weight.data.copy_(torch.from_numpy(U))
    self.movie_matrix.weight.data.copy_(torch.from_numpy(V))
    
    torch.nn.init.zeros_(self.user_biases.weight)
    torch.nn.init.zeros_(self.movie_biases.weight)
    torch.nn.init.zeros_(self.global_biases.weight)

# %%
#@title Step 7: Instantiate model
model = SVDpp(number_of_users, number_of_movies, rank=20, biased=True)

# put the model in the device memory
model = model.to(device)

# count total number of parameters including non trainable
total_params_count = sum(p.numel() for p in model.parameters())
# count total trainable parameters
trainable_params_count = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total number of trainable parameters: {total_params_count}")
print(f"Number of trainable parameters: {trainable_params_count}")
# Out:
# Total number of trainable parameters: 231001
# Number of trainable parameters: 231001

# %%
#@title Step 8: Embedding initialization

def weights_init(m):
    if isinstance(m, torch.nn.Embedding):
        torch.nn.init.xavier_uniform_(m.weight.data)

# whether use SVD-based embedding intialization
svd_init = False

if svd_init:
  model.SVD_init()
else:
  model.apply(weights_init)

# %%
#@title Step 9: Loss and optimizer

loss_func = torch.nn.MSELoss()


learning_rate  = 3e-4
regularization = 5e-5
optimizer_user  = torch.optim.Adam([model.user_matrix.weight , model.user_biases.weight], lr=learning_rate, weight_decay=regularization)
optimizer_movie = torch.optim.Adam([model.movie_matrix.weight, model.movie_biases.weight, model.global_biases.weight], lr=learning_rate, weight_decay=regularization)
optimizer_all   = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=regularization)

# %%
#@title Step 10: Training and validation

# set seed to make result reproducible
torch.manual_seed(0)

# number of epochs
n_epochs = 30

# whether to train in ALS style (optimize U and V alternatively)
# or in normal style
ALS_train = False

# whether to train with 90% data and validate with 10%,
# or to train with 100% data
validate = True

if validate:
    t_loader = train_loader
else:
    t_loader = all_loader
  

step = 0
for epoch in range(n_epochs):
    
    # train model
    model.train()
    total_loss_train, total_accuracy_train = 0., 0.
    for i, (user, movie, rating) in enumerate(t_loader):
       
        if ALS_train: 
            optimizer_user.zero_grad()  
            output = model(user, movie) 
            loss = loss_func(output, rating) 
            loss.backward() 
            optimizer_user.step()

            optimizer_movie.zero_grad()
            output = model(user, movie)
            loss = loss_func(output, rating)
            loss.backward()
            optimizer_movie.step()
        else:
            optimizer_all.zero_grad()   
            output = model(user, movie) 
            loss = loss_func(output, rating) 
            loss.backward() 
            optimizer_all.step() 

        total_loss_train += loss.item()
        
        # measure accuracy
        if validate:
            total_accuracy_train += (output.round() == rating).float().sum()
        
        if step % 5000 == 0:
            print('[Epoch %03d] - Step %04d> train loss: %.4f' % (epoch, step, loss.item()))
        step += 1


    # validate model
    if validate:
        model.eval()
        total_loss_test, total_accuracy_test = 0., 0.
        with torch.no_grad():
            for i, (user, movie, rating) in enumerate(test_loader):
                output = model(user, movie)
                loss = loss_func(output, rating)

                total_loss_test += loss.item()
                total_accuracy_test += (output.round() == rating).float().sum()

                if step % 5000 == 0:
                    print('[Epoch %03d] - Step %04d> test  loss: %.4f' % (epoch, step, loss.item()))      



    total_loss_train /= len(t_loader)
    print('[Epoch %03d] - > avg train loss: %.4f' % (epoch, total_loss_train)) 

    if validate:
        total_loss_test  /= len(test_loader) 
        total_accuracy_train /= (len(t_loader)*batch_size)
        total_accuracy_test  /= (len(test_loader)*batch_size)     
    
        print('[Epoch %03d] - > avg test  loss: %.4f' % (epoch, total_loss_test))
        print('[Epoch %03d] - > avg train accu: %.4f' % (epoch, total_accuracy_train)) 
        print('[Epoch %03d] - > avg test  accu: %.4f' % (epoch, total_accuracy_test))
# Out:
# [Epoch 000] - Step 0000> train loss: 6.8635
# [Epoch 000] - Step 5000> train loss: 1.1584
# [Epoch 000] - Step 10000> train loss: 0.7667
# [Epoch 000] - Step 15000> train loss: 0.8078
# [Epoch 000] - > avg train loss: 1.3345
# [Epoch 000] - > avg test  loss: 1.0178
# [Epoch 000] - > avg train accu: 0.2795
# [Epoch 000] - > avg test  accu: 0.3531
# [Epoch 001] - Step 20000> train loss: 0.8426
# [Epoch 001] - Step 25000> train loss: 1.3053
# [Epoch 001] - Step 30000> train loss: 0.9569
# [Epoch 001] - > avg train loss: 1.0024
# [Epoch 001] - > avg test  loss: 1.0078
# [Epoch 001] - > avg train accu: 0.3556
# [Epoch 001] - > avg test  accu: 0.3534
# [Epoch 002] - Step 35000> train loss: 1.1357
# [Epoch 002] - Step 40000> train loss: 0.8611
# [Epoch 002] - Step 45000> train loss: 1.0711
# [Epoch 002] - > avg train loss: 0.9974
# [Epoch 002] - > avg test  loss: 1.0013
# [Epoch 002] - > avg train accu: 0.3581
# [Epoch 002] - > avg test  accu: 0.3558
# [Epoch 003] - Step 50000> train loss: 1.0475
# [Epoch 003] - Step 55000> train loss: 1.0348
# [Epoch 003] - Step 60000> train loss: 1.0753
# [Epoch 003] - Step 65000> train loss: 0.7959
# [Epoch 003] - > avg train loss: 0.9935
# [Epoch 003] - > avg test  loss: 0.9955
# [Epoch 003] - > avg train accu: 0.3612
# [Epoch 003] - > avg test  accu: 0.3585
# [Epoch 004] - Step 70000> train loss: 0.9773
# [Epoch 004] - Step 75000> train loss: 1.1731
# [Epoch 004] - Step 80000> train loss: 1.0386
# [Epoch 004] - > avg train loss: 0.9894
# [Epoch 004] - > avg test  loss: 0.9894
# [Epoch 004] - > avg train accu: 0.3638
# [Epoch 004] - > avg test  accu: 0.3594
# [Epoch 005] - Step 85000> train loss: 1.3829
# [Epoch 005] - Step 90000> train loss: 0.6758
# [Epoch 005] - Step 95000> train loss: 1.0236
# [Epoch 005] - > avg train loss: 0.9850
# [Epoch 005] - > avg test  loss: 0.9845
# [Epoch 005] - > avg train accu: 0.3669
# [Epoch 005] - > avg test  accu: 0.3612
# [Epoch 006] - Step 100000> train loss: 0.8500
# [Epoch 006] - Step 105000> train loss: 1.1256
# [Epoch 006] - Step 110000> train loss: 0.9862
# [Epoch 006] - Step 115000> train loss: 0.9406
# [Epoch 006] - > avg train loss: 0.9811
# [Epoch 006] - > avg test  loss: 0.9799
# [Epoch 006] - > avg train accu: 0.3695
# [Epoch 006] - > avg test  accu: 0.3647
# [Epoch 007] - Step 120000> train loss: 0.9534
# [Epoch 007] - Step 125000> train loss: 1.1772
# [Epoch 007] - Step 130000> train loss: 1.0725
# [Epoch 007] - > avg train loss: 0.9779
# [Epoch 007] - > avg test  loss: 0.9769
# [Epoch 007] - > avg train accu: 0.3720
# [Epoch 007] - > avg test  accu: 0.3654
# [Epoch 008] - Step 135000> train loss: 0.9715
# [Epoch 008] - Step 140000> train loss: 0.8258
# [Epoch 008] - Step 145000> train loss: 1.0621
# [Epoch 008] - > avg train loss: 0.9749
# [Epoch 008] - > avg test  loss: 0.9744
# [Epoch 008] - > avg train accu: 0.3747
# [Epoch 008] - > avg test  accu: 0.3668
# [Epoch 009] - Step 150000> train loss: 0.8440
# [Epoch 009] - Step 155000> train loss: 1.0534
# [Epoch 009] - Step 160000> train loss: 0.9730
# [Epoch 009] - Step 165000> train loss: 0.7154
# [Epoch 009] - > avg train loss: 0.9719
# [Epoch 009] - > avg test  loss: 0.9716
# [Epoch 009] - > avg train accu: 0.3766
# [Epoch 009] - > avg test  accu: 0.3699
# [Epoch 010] - Step 170000> train loss: 1.0719
# [Epoch 010] - Step 175000> train loss: 0.6514
# [Epoch 010] - Step 180000> train loss: 1.0016
# [Epoch 010] - > avg train loss: 0.9689
# [Epoch 010] - > avg test  loss: 0.9691
# [Epoch 010] - > avg train accu: 0.3783
# [Epoch 010] - > avg test  accu: 0.3690
# [Epoch 011] - Step 185000> train loss: 0.8748
# [Epoch 011] - Step 190000> train loss: 0.8861
# [Epoch 011] - Step 195000> train loss: 0.7332
# [Epoch 011] - > avg train loss: 0.9657
# [Epoch 011] - > avg test  loss: 0.9672
# [Epoch 011] - > avg train accu: 0.3804
# [Epoch 011] - > avg test  accu: 0.3705
# [Epoch 012] - Step 200000> train loss: 1.0745
# [Epoch 012] - Step 205000> train loss: 0.8021
# [Epoch 012] - Step 210000> train loss: 0.7385
# [Epoch 012] - Step 215000> train loss: 0.8624
# [Epoch 012] - > avg train loss: 0.9626
# [Epoch 012] - > avg test  loss: 0.9655
# [Epoch 012] - > avg train accu: 0.3822
# [Epoch 012] - > avg test  accu: 0.3703
# [Epoch 013] - Step 220000> train loss: 0.9800
# [Epoch 013] - Step 225000> train loss: 0.7766
# [Epoch 013] - Step 230000> train loss: 1.0266
# [Epoch 013] - > avg train loss: 0.9597
# [Epoch 013] - > avg test  loss: 0.9643
# [Epoch 013] - > avg train accu: 0.3842
# [Epoch 013] - > avg test  accu: 0.3705
# [Epoch 014] - Step 235000> train loss: 0.9474
# [Epoch 014] - Step 240000> train loss: 1.1765
# [Epoch 014] - Step 245000> train loss: 1.0125
# [Epoch 014] - > avg train loss: 0.9568
# [Epoch 014] - > avg test  loss: 0.9632
# [Epoch 014] - > avg train accu: 0.3859
# [Epoch 014] - > avg test  accu: 0.3716
# [Epoch 015] - Step 250000> train loss: 0.9873
# [Epoch 015] - Step 255000> train loss: 1.3238
# [Epoch 015] - Step 260000> train loss: 1.1697
# [Epoch 015] - > avg train loss: 0.9540
# [Epoch 015] - > avg test  loss: 0.9621
# [Epoch 015] - > avg train accu: 0.3876
# [Epoch 015] - > avg test  accu: 0.3736
# [Epoch 016] - Step 265000> train loss: 0.9502
# [Epoch 016] - Step 270000> train loss: 0.6774
# [Epoch 016] - Step 275000> train loss: 0.8714
# [Epoch 016] - Step 280000> train loss: 1.1367
# [Epoch 016] - > avg train loss: 0.9514
# [Epoch 016] - > avg test  loss: 0.9615
# [Epoch 016] - > avg train accu: 0.3896
# [Epoch 016] - > avg test  accu: 0.3731
# [Epoch 017] - Step 285000> train loss: 0.7223
# [Epoch 017] - Step 290000> train loss: 1.3312
# [Epoch 017] - Step 295000> train loss: 0.7019
# [Epoch 017] - > avg train loss: 0.9489
# [Epoch 017] - > avg test  loss: 0.9608
# [Epoch 017] - > avg train accu: 0.3908
# [Epoch 017] - > avg test  accu: 0.3731
# [Epoch 018] - Step 300000> train loss: 0.8000
# [Epoch 018] - Step 305000> train loss: 0.9321
# [Epoch 018] - Step 310000> train loss: 0.9234
# [Epoch 018] - > avg train loss: 0.9464
# [Epoch 018] - > avg test  loss: 0.9608
# [Epoch 018] - > avg train accu: 0.3924
# [Epoch 018] - > avg test  accu: 0.3736
# [Epoch 019] - Step 315000> train loss: 1.2187
# [Epoch 019] - Step 320000> train loss: 0.7180
# [Epoch 019] - Step 325000> train loss: 0.9374
# [Epoch 019] - Step 330000> train loss: 0.9409
# [Epoch 019] - > avg train loss: 0.9440
# [Epoch 019] - > avg test  loss: 0.9604
# [Epoch 019] - > avg train accu: 0.3938
# [Epoch 019] - > avg test  accu: 0.3744
# [Epoch 020] - Step 335000> train loss: 0.6083
# [Epoch 020] - Step 340000> train loss: 0.9863
# [Epoch 020] - Step 345000> train loss: 0.7344
# [Epoch 020] - > avg train loss: 0.9418
# [Epoch 020] - > avg test  loss: 0.9602
# [Epoch 020] - > avg train accu: 0.3954
# [Epoch 020] - > avg test  accu: 0.3745
# [Epoch 021] - Step 350000> train loss: 0.7928
# [Epoch 021] - Step 355000> train loss: 1.0768
# [Epoch 021] - Step 360000> train loss: 0.8215
# [Epoch 021] - > avg train loss: 0.9397
# [Epoch 021] - > avg test  loss: 0.9600
# [Epoch 021] - > avg train accu: 0.3964
# [Epoch 021] - > avg test  accu: 0.3749
# [Epoch 022] - Step 365000> train loss: 0.6683
# [Epoch 022] - Step 370000> train loss: 1.0607
# [Epoch 022] - Step 375000> train loss: 0.8508
# [Epoch 022] - Step 380000> train loss: 0.8443
# [Epoch 022] - > avg train loss: 0.9377
# [Epoch 022] - > avg test  loss: 0.9601
# [Epoch 022] - > avg train accu: 0.3978
# [Epoch 022] - > avg test  accu: 0.3761
# [Epoch 023] - Step 385000> train loss: 0.9772
# [Epoch 023] - Step 390000> train loss: 1.1339
# [Epoch 023] - Step 395000> train loss: 0.9759
# [Epoch 023] - > avg train loss: 0.9359
# [Epoch 023] - > avg test  loss: 0.9603
# [Epoch 023] - > avg train accu: 0.3988
# [Epoch 023] - > avg test  accu: 0.3750
# [Epoch 024] - Step 400000> train loss: 0.7972
# [Epoch 024] - Step 405000> train loss: 0.7848
# [Epoch 024] - Step 410000> train loss: 0.9542
# [Epoch 024] - > avg train loss: 0.9341
# [Epoch 024] - > avg test  loss: 0.9603
# [Epoch 024] - > avg train accu: 0.3998
# [Epoch 024] - > avg test  accu: 0.3757
# [Epoch 025] - Step 415000> train loss: 0.8147
# [Epoch 025] - Step 420000> train loss: 0.7211
# [Epoch 025] - Step 425000> train loss: 0.9062
# [Epoch 025] - Step 430000> train loss: 0.8518
# [Epoch 025] - > avg train loss: 0.9327
# [Epoch 025] - > avg test  loss: 0.9605
# [Epoch 025] - > avg train accu: 0.4007
# [Epoch 025] - > avg test  accu: 0.3754
# [Epoch 026] - Step 435000> train loss: 0.5995
# [Epoch 026] - Step 440000> train loss: 0.8203
# [Epoch 026] - Step 445000> train loss: 1.0824
# [Epoch 026] - > avg train loss: 0.9313
# [Epoch 026] - > avg test  loss: 0.9608
# [Epoch 026] - > avg train accu: 0.4015
# [Epoch 026] - > avg test  accu: 0.3758
# [Epoch 027] - Step 450000> train loss: 0.9310
# [Epoch 027] - Step 455000> train loss: 0.8273
# [Epoch 027] - Step 460000> train loss: 0.7489
# [Epoch 027] - > avg train loss: 0.9301
# [Epoch 027] - > avg test  loss: 0.9611
# [Epoch 027] - > avg train accu: 0.4024
# [Epoch 027] - > avg test  accu: 0.3759
# [Epoch 028] - Step 465000> train loss: 0.6629
# [Epoch 028] - Step 470000> train loss: 0.7874
# [Epoch 028] - Step 475000> train loss: 0.8805
# [Epoch 028] - > avg train loss: 0.9290
# [Epoch 028] - > avg test  loss: 0.9613
# [Epoch 028] - > avg train accu: 0.4029
# [Epoch 028] - > avg test  accu: 0.3760
# [Epoch 029] - Step 480000> train loss: 0.5978
# [Epoch 029] - Step 485000> train loss: 0.8944
# [Epoch 029] - Step 490000> train loss: 1.4306
# [Epoch 029] - Step 495000> train loss: 0.7693
# [Epoch 029] - > avg train loss: 0.9280
# [Epoch 029] - > avg test  loss: 0.9616
# [Epoch 029] - > avg train accu: 0.4034
# [Epoch 029] - > avg test  accu: 0.3777

# %%
#@title Step 11: Generate predictions

submission_users, submission_movies, submission_predictions = extract_users_items_predictions(submission_pd)
print(submission_users)
print(submission_movies)
print(submission_predictions)

submission_users_  = torch.tensor(submission_users, device=device).int()
submission_movies_ = torch.tensor(submission_movies, device=device).int()

model.eval()
with torch.no_grad():
    output = model(submission_users_, submission_movies_)

output = output.to('cpu')
print(output)

# %%
#@title Step 12: Clamp output in range 1.0 ~ 5.0

print(output.min())
print(output.max())
print()

output = torch.clamp(output, min=1.0, max=5.0)
print(output.min())
print(output.max())
print()
# Out:
# tensor(1.)
# tensor(5.)
#
# tensor(1.)
# tensor(5.)

# %%
#@title Step 13: Generate .csv submission file

submission_users = (submission_users+1).astype(str)
submission_users = np.char.add('r', submission_users)

submission_movies = (submission_movies+1).astype(str)
submission_movies = np.char.add('_c', submission_movies)

submission_IDs = np.char.add(submission_users, submission_movies)

my_submission = pd.DataFrame({'ID': submission_IDs, 'Prediction': output})

print(my_submission.head(10))

my_submission.to_csv("my_submission.csv", index=False)

# re-check
wtf = pd.read_csv('my_submission.csv')
wtf.head(10)
# Out:
#         ID  Prediction
# 0   r37_c1         3.0
# 1   r73_c1         3.0
# 2  r156_c1         4.0
# 3  r160_c1         3.0
# 4  r248_c1         3.0
# 5  r256_c1         3.0
# 6  r284_c1         3.0
# 7  r400_c1         3.0
# 8  r416_c1         4.0
# 9  r456_c1         3.0
#         ID  Prediction
# 0   r37_c1         3.0
# 1   r73_c1         3.0
# 2  r156_c1         4.0
# 3  r160_c1         3.0
# 4  r248_c1         3.0
# 5  r256_c1         3.0
# 6  r284_c1         3.0
# 7  r400_c1         3.0
# 8  r416_c1         4.0
# 9  r456_c1         3.0
